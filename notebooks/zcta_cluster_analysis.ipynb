# %% [markdown]
# ## ZCTA Analysis

# %%
import pandas
import numpy
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from scipy.spatial import distance
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from datetime import datetime

# %%
#importing ZCTA Data 
# first is the full US ZCTA dataset
data = pandas.read_csv('1.csv');
data.set_index('ZCTA5')
# second is the ZCTA dataset used in the main analysis
data1 = pandas.read_csv('2.csv');
data1.set_index('ZCTA5')
# data below shows the percentage of people that have identified as part of a certain demographic for a given ZCTA
# Out:
#        white  black  hispanic_or_latino
# ZCTA5
# 601    0.811  0.006               0.998
# 602    0.578  0.024               0.935
# 603    0.682  0.042               0.968
# 606    0.592  0.028               0.998
# 610    0.581  0.036               0.979
# ...      ...    ...                 ...
# 99922  0.048  0.000               0.000
# 99925  0.468  0.006               0.020
# 99926  0.115  0.000               0.082
# 99927  0.914  0.000               0.000
# 99929  0.673  0.003               0.030
#
# [32740 rows x 3 columns]

# %%
# shaping data to get ready for display
X = numpy.array(data.iloc[:, 1:3])
Y = numpy.array(data.iloc[:, 3])

valid_samples = Y > 0
X_cleaned = X[valid_samples, :]
Y_cleaned = Y[valid_samples]

X1 = numpy.array(data1.iloc[:, 1:3])
Y1 = numpy.array(data1.iloc[:, 3])

valid_samples = Y1 > 0
X1_cleaned = X1[valid_samples, :]
Y1_cleaned = Y1[valid_samples]

# %%
# Displaying the full dataset of ZCTAs
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.scatter(X1[:,0], X1[:, 1], X1[:, 1], c=Y1)

# %%
# Displaying the restricted dataset of ZCTAs
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.scatter(X[:,0], X[:, 1], X[:, 1], c=Y)
